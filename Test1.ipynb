# %% [markdown]
# <a href="https://colab.research.google.com/github/HelithaNimnaka/EN3160_Image_Processing/blob/main/Test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import matplotlib.pyplot as plt
from google.colab import drive
#drive.mount('/content/drive')
os.chdir('/content')
img = plt.imread('emma.jpg')
plt.imshow(img)
